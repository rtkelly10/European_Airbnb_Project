# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#path to project
path = r'C:\Users\rtkel\Documents\Data Analytics Course\European Cities Airbnb Project'

# %%
path
# Out:
# 'C:\\Users\\rtkel\\Documents\\Data Analytics Course\\European Cities Airbnb Project'

# %%
# check the version of matplot
matplotlib.__version__
# Out:
# '3.7.1'

# %%
# Ensure charts are displayed in notebook
# %matplotlib inline

# %%
#import data set
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'merged_df.csv'), index_col = False)

# %%
#check import of data
df.shape
# Out:
# (51707, 21)

# %%
df.head()
# Out:
#    Unnamed: 0       City Time of Week     Room Type  Room Shared  \
# 0           0  Amsterdam      Weekday  Private room        False
# 1           1  Amsterdam      Weekday  Private room        False
# 2           2  Amsterdam      Weekday  Private room        False
# 3           3  Amsterdam      Weekday  Private room        False
# 4           4  Amsterdam      Weekday  Private room        False
#
#    Room Private  Person Capacity  Multiple Rooms  Business Listing  \
# 0          True              2.0               1                 0
# 1          True              4.0               0                 0
# 2          True              2.0               0                 1
# 3          True              4.0               0                 1
# 4          True              2.0               0                 0
#
#    Number of Bedrooms  ...  Cleanliness Rating  \
# 0                   1  ...                10.0
# 1                   1  ...                 8.0
# ...

# %% [markdown]
# ### Step 2 - Pick Variables

# %%
df_sub = df.drop(['Unnamed: 0', 'City', 'Time of Week', 'Room Type', 'Room Shared', 'Room Private', 
                  'Person Capacity', 'Multiple Rooms', 'Business Listing', 'Longitude','Latitude'], axis=1)

# %%
df_sub.head()
# Out:
#    Number of Bedrooms  Total Price  Cleanliness Rating  \
# 0                   1   194.033698                10.0
# 1                   1   344.245776                 8.0
# 2                   1   264.101422                 9.0
# 3                   2   433.529398                 9.0
# 4                   1   485.552926                10.0
#
#    Overall Guest Satisfaction Rating  Distance from City Centre  \
# 0                               93.0                   5.022964
# 1                               85.0                   0.488389
# 2                               87.0                   5.748312
# 3                               90.0                   0.384862
# 4                               98.0                   0.544738
#
#    Distance from Nearest Metro Station  Attraction Index  \
# 0                             2.539380         78.690379
# 1                             0.239404        631.176378
# 2                             3.651621         75.275877
# ...

# %% [markdown]
# ### Step 3 - Create Heatmap

# %%
#Create correlation table between variables
df_sub.corr()
# Out:
#                                      Number of Bedrooms  Total Price  \
# Number of Bedrooms                             1.000000     0.221653
# Total Price                                    0.221653     1.000000
# Cleanliness Rating                             0.033489    -0.006082
# Overall Guest Satisfaction Rating              0.047573    -0.001888
# Distance from City Centre                     -0.006262    -0.044725
# Distance from Nearest Metro Station            0.044431    -0.061025
# Attraction Index                              -0.011735     0.178228
# Normalized Attraction Index                   -0.063773     0.292396
# Restaurant Index                              -0.014047     0.134722
# Normalized Restaurant Index                   -0.057726     0.144094
#
#                                      Cleanliness Rating  \
# Number of Bedrooms                             0.033489
# Total Price                                   -0.006082
# ...

# %%
# Creating subplot using matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Creating matrix heatmap using seaborn
corr = sns.heatmap(df_sub.corr(), annot = True, ax = ax)

# %%
# Scatterplots of most correlated variables
# Overall Guest Satisfaction Rating and Cleanliness Rating scatterplot
sns.lmplot(x = 'Overall Guest Satisfaction Rating', y = 'Cleanliness Rating', data = df_sub)

# %% [markdown]
# #### 'Number of Bedrooms' demonstrates a mild positive correlation with 'Total Price', hinting at the impact of property size on pricing. 'Cleanliness Rating' exhibits a noteworthy positive correlation with 'Overall Guest Satisfaction Rating', emphasizing the importance of cleanliness in shaping guests' overall satisfaction. The negative correlation between 'Distance from City Centre' and various indices ('Attraction Index', 'Normalized Attraction Index', 'Restaurant Index', 'Normalized Restaurant Index') suggests that properties closer to the city center tend to be associated with higher attraction and restaurant indices. Additionally, the negative correlation between 'Distance from City Centre' and 'Total Price' indicates that properties closer to the city center may command higher prices. These correlations offer valuable insights into the factors influencing property prices and guest satisfaction, laying the foundation for further exploratory analysis.

# %% [markdown]
# ### Step 4 - Create scatterplots

# %%
# Scatterplot of Total Price vs Normalized Attraction Index
plot = sns.lmplot(x='Total Price', y='Normalized Attraction Index', data=df_sub)

# Set the x-axis limit
plot.set(xlim=(0, 4000))

# Show the plot
plt.show()

# %%
# Scatterplot of Total Price vs Disatnce from City Centre
plot = sns.lmplot(x='Total Price', y='Distance from City Centre', data=df_sub)

# Set the x-axis limit
plot.set(xlim=(0, 4000))

# Show the plot
plt.show()

# %%
# Scatterplots of most correlated variables
# Distance from City Centre and Normalized Restaurant Index
sns.lmplot(x = 'Distance from City Centre', y = 'Normalized Restaurant Index', data = df_sub)

# %%
# Scatterplots of most correlated variables
# Overall Guest Satisfaction Rating and Cleanliness Rating
sns.lmplot(x = 'Overall Guest Satisfaction Rating', y = 'Cleanliness Rating', data = df_sub)

# %% [markdown]
# #### The positive relationship between 'Total Price' and 'Normalized Attraction Index' suggests that properties with higher prices tend to be closer to attractions. Conversely, the negative correlation observed between 'Distance from City Centre' and 'Normalized Restaurant Index' indicates that as properties approach the city center, they exhibit a higher density of nearby restaurants. Additionally, the scatter plot for 'Overall Guest Satisfaction Rating' and 'Cleanliness Rating' depicts a positive correlation, suggesting that higher cleanliness ratings contribute to elevated overall guest satisfaction.

# %% [markdown]
# ### Step 5 - Create a pairplot

# %%
# Creating a pairplot
pair_plot = sns.pairplot(df_sub)

# %% [markdown]
# #### The scatter plots provided align well with the previously calculated correlations, offering a visual confirmation of the observed relationships in the correlation matrix. Particularly, the plots highlight substantial connections between 'Overall Guest Satisfaction Rating' and 'Cleanliness Rating,' supporting the strong positive correlation identified in the correlation table. Similarly, the scatter plots affirm the anticipated strong associations between 'Attraction Index' and 'Restaurant Index,' reinforcing the high correlation coefficient between these variables.

# %% [markdown]
# ### Step 6 - Create categorical plots

# %%
# Histogram to see distribution
sns.histplot(df_sub['Total Price'], bins = 100, kde = True)

# %%
# Apply a log transformation to the data
df_sub['Total Price Log'] = np.log1p(df_sub['Total Price'])

# %%
# Plot the histogram with the transformed data
sns.histplot(df_sub['Total Price Log'], bins=10, kde=True)
plt.xlabel('Log-transformed Total Price')
plt.show()

# %%
# Creating low score category for categorical plot
df_sub.loc[df_sub['Total Price Log'] < 5 , 'Price category'] = 'Low price'

# %%
# Creating medium score category for categorical plot
df_sub.loc[(df_sub['Total Price Log'] >= 5) & (df_sub['Total Price Log'] < 6), 'Price category'] = 'Middle price'

# %%
# Creating low score category for categorical plot
df_sub.loc[df_sub['Total Price Log'] >= 6 , 'Price category'] = 'High price'

# %%
df_sub['Price category'].value_counts(dropna = False)

# %%
# Creating categorical plot with Normalized Attraction Indez
sns.set(style="ticks")
cat_plot_GDP = sns.catplot(x='Normalized Attraction Index', y='Total Price Log', hue="Price category", data=df_sub)

# %% [markdown]
# #### This analysis reveals a positive correlation between property prices, represented by the logarithmically transformed 'Total Price,' and the 'Normalized Attraction Index.' As the attraction index increases, indicating higher proximity to attractions, there is a corresponding upward trend in property prices. The Seaborn categorical plot effectively captures this positive correlation by visually showcasing how the 'Total Price' varies across different levels of the 'Normalized Attraction Index,' offering valuable insights into the relationship between these two variables.

# %% [markdown]
# ### Step 7 - Revisit Questions

# %% [markdown]
# **Question 1: Answers and New Questions**
#
# 1. **How do Airbnb prices vary across different European cities?**
#    - *Answer:* The visual exploration of the dataset indicates significant variability in Airbnb prices across European cities. Cities such as London, Paris, and Rome tend to have higher average prices compared to others. Further statistical analyses, including measures of central tendency and dispersion, will provide more precise insights into the range and distribution of prices.
#    - *New Questions:* What are the specific factors contributing to the observed variations in prices across different cities? Are there any seasonal trends influencing price fluctuations?
#
# 2. **What are the key factors contributing to guest satisfaction in Airbnb listings?**
#    - *Answer:* The scatter plot analysis suggests a strong positive correlation between 'Cleanliness Rating' and 'Overall Guest Satisfaction Rating,' highlighting the importance of cleanliness in influencing guest satisfaction. Multivariate analysis will be crucial to identify additional factors contributing significantly to guest satisfaction.
#    - *New Questions:* Are there specific amenities or property features that correlate strongly with guest satisfaction? How do factors such as communication with hosts or ease of check-in contribute to overall satisfaction?
#
# 3. **Does the distance from the city center influence both the pricing and overall guest satisfaction of Airbnb listings, and is there a relationship between these two factors?**
#    - *Answer:* Preliminary findings suggest a negative correlation between 'Distance from City Centre' and both 'Total Price' and 'Overall Guest Satisfaction Rating.' However, more advanced statistical modeling, such as regression analysis, is needed to understand the complex relationships and potential moderating effects.
#    - *New Questions:* How do different cities exhibit variations in the impact of distance from the city center on pricing and satisfaction? Are there specific thresholds beyond which distance significantly influences these factors?
#
# 4. **What is the relationship between a host's superhost status and both the pricing and cleanliness ratings of their listings?**
#    - *Answer:* The analysis has not been conducted yet. Further exploration is required to understand if there is a correlation between a host's superhost status and pricing and cleanliness ratings.
#    - *New Questions:* Does superhost status uniformly correlate with higher pricing and cleanliness ratings across all cities? Are there variations in the impact of superhost status based on regional differences?
#
# 5. **Are there regional patterns or clusters where both pricing and overall guest satisfaction align, indicating a geographical relationship?**
#    - *Answer:* The exploration has identified potential regional patterns, but more advanced clustering techniques are needed to substantiate these observations.
#    - *New Questions:* What specific geographical features or characteristics contribute to the identified regional patterns? How stable are these patterns over time, and are there temporal trends influencing them?
#
# 6. **Is there a correlation between the attraction index (proximity to attractions) or distance to the city center and overall guest satisfaction, and does this relationship vary across cities?**
#    - *Answer:* The initial correlation analysis suggests a potential relationship between the attraction index, distance to the city center, and overall guest satisfaction. Further city-specific analyses are required to understand variations.
#    - *New Questions:* How do different cities exhibit variations in the impact of proximity to attractions on overall guest satisfaction? Are there city-specific factors moderating this relationship?

# %% [markdown]
# ### Step 8 - Define Hypotheses

# %% [markdown]
# 1. If the 'Cleanliness Rating' is higher, then the 'Overall Guest Satisfaction Rating' will also be higher, indicating a positive correlation between cleanliness ratings and overall guest satisfaction.
#
# 2. If a property is closer to the city center, then the 'Total Price' is likely to be higher, implying a positive correlation between 'Total Price' and 'Distance from City Centre,' suggesting that properties closer to the city center tend to have higher prices.
#
# 3. If we examine the impact of proximity to attractions on overall guest satisfaction across different European cities, then we will find significant differences, with variations attributed to city-specific factors.
